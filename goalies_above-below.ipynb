# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime, timedelta, timezone
import pytz
import scipy.stats
from dateutil.relativedelta import relativedelta

import warnings

# Suppress the specific warnings
warnings.filterwarnings("ignore")

today = datetime.utcnow()

from api_keys import espn_link

# %%
homeOnlySked = pd.read_csv('data/sked.csv', index_col=False)
homeOnlySked

completeSked = pd.read_csv('data/sked_full.csv', index_col=False)
completeSked

team_names = pd.read_csv('data/team_names.csv', index_col=False)
team_names

file_name = f"data/allG_df_fp-{today.strftime('%Y-%m-%d')}.csv"
allG_df = pd.read_csv(file_name, index_col=False)
allG_df

file_name = f"data/all_df_fp-{today.strftime('%Y-%m-%d')}.csv"
all_df = pd.read_csv(file_name, index_col=False)
all_df

file_name = f"data/summary_statsG-{today.strftime('%Y-%m-%d')}.csv"
summary_statsG = pd.read_csv(file_name, index_col=False)

file_name = f"data/summary_statsS-{today.strftime('%Y-%m-%d')}.csv"
summary_statsS = pd.read_csv(file_name, index_col=False)

team_names_only = team_names[['abbreviation', 'name']]

all_df_forwards =  all_df.loc[all_df['position'] != 'D']
all_df_defense =  all_df.loc[all_df['position'] == 'D']

all_df_centers =  all_df.loc[all_df['secondaryPosition'] == 'C']
all_df_wingers =  all_df.loc[all_df['secondaryPosition'] == 'W']

file_name = f"data/summary_stats-{today.strftime('%Y-%m-%d')}.csv"
player_bios = pd.read_csv(file_name, index_col=False)

# %%
espn_teams = {
    'BOS': 'Bos',
    'VGK': 'Vgk',
    'NYR': 'NYR',
    'VAN': 'Van',
    'LAK': 'LA',
    'DAL': 'Dal',
    'FLA': 'Fla',
    'COL': 'Col',
    'WPG': 'Wpg',
    'TOR': 'Tor',
    'WSH': 'Wsh',
    'CAR': 'Car',
    'TBL': 'TB',
    'PHI': 'Phi',
    'DET': 'Det',
    'ANA': 'Ana',
    'ARI': 'Ari',
    'SEA': 'Sea',
    'NJD': 'NJ',
    'STL': 'StL',
    'NYI': 'NYI',
    'OTT': 'Ott',
    'PIT': 'Pit',
    'MTL': 'Mon',
    'BUF': 'Buf',
    'CGY': 'Cgy',
    'MIN': 'Min',
    'NSH': 'Nsh',
    'CBJ': 'Cls',
    'EDM': 'Edm',
    'CHI': 'Chi',
    'SJS': 'SJ'
}

team_names_only['espn_name'] = team_names_only['abbreviation'].map(espn_teams)
team_names_only
# Out:
#    abbreviation                   name espn_name
# 0           NYR       New York Rangers       NYR
# 1           BOS          Boston Bruins       Bos
# 2           VGK   Vegas Golden Knights       Vgk
# 3           COL     Colorado Avalanche       Col
# 4           LAK      Los Angeles Kings        LA
# 5           VAN      Vancouver Canucks       Van
# 6           FLA       Florida Panthers       Fla
# 7           DAL           Dallas Stars       Dal
# 8           WPG          Winnipeg Jets       Wpg
# 9           DET      Detroit Red Wings       Det
# 10          TBL    Tampa Bay Lightning        TB
# 11          CAR    Carolina Hurricanes       Car
# 12          TOR    Toronto Maple Leafs       Tor
# 13          STL        St. Louis Blues       StL
# 14          PHI    Philadelphia Flyers       Phi
# 15          WSH    Washington Capitals       Wsh
# 16          NYI     New York Islanders       NYI
# 17          BUF         Buffalo Sabres       Buf
# 18          CGY         Calgary Flames       Cgy
# 19          SEA         Seattle Kraken       Sea
# 20          PIT    Pittsburgh Penguins       Pit
# 21          NSH    Nashville Predators       Nsh
# 22          ARI        Arizona Coyotes       Ari
# 23          MTL     Montréal Canadiens       Mon
# 24          NJD      New Jersey Devils        NJ
# 25          ANA          Anaheim Ducks       Ana
# 26          CBJ  Columbus Blue Jackets       Cls
# 27          OTT        Ottawa Senators       Ott
# 28          EDM        Edmonton Oilers       Edm
# 29          MIN         Minnesota Wild       Min
# 30          CHI     Chicago Blackhawks       Chi
# 31          SJS        San Jose Sharks        SJ

# %%
allG_df['fantasyPoints'].describe()
# Out:
# count    695.000000
# mean       1.720863
# std        5.177196
# min      -14.800000
# 25%       -2.400000
# 50%        1.400000
# 75%        5.500000
# max       15.200000
# Name: fantasyPoints, dtype: float64

# %%
goalies = player_bios.loc[player_bios['position'] == 'G']
for index, row in allG_df.iterrows():
    allG_df.at[index, 'available'] = round(100 - goalies.loc[goalies['playerId'] == row['playerId'], 'roster_percent'].iloc[0], 2)

    
allG_df
# Out:
#      playerId  sweaterNumber            name position  pim  goalsAgainst  \
# 0     8477992             31    J. Johansson        G    0             3
# 1     8477465             35        T. Jarry        G    0             3
# 2     8478499             33         A. Hill        G    0             1
# 3     8475883             31     F. Andersen        G    0             3
# 4     8478492             35     I. Samsonov        G    0             5
# ..        ...            ...             ...      ...  ...           ...
# 690   8480045              1    U. Luukkonen        G    0             1
# 691   8475683             72    S. Bobrovsky        G    0             0
# 692   8476883             88  A. Vasilevskiy        G    0             3
# 693   8478499             33         A. Hill        G    0             2
# 694   8475311             35      D. Kuemper        G    0             2
#
#       toi team opponent             gameDate  ... saves  shots  evSaves  \
# 0    3600  TBL      NSH           2023-10-10  ...    28     31       21
# 1    3450  PIT      CHI           2023-10-10  ...    32     35       26
# 2    3600  VGK      SEA           2023-10-10  ...    32     33       22
# 3    3600  CAR      OTT           2023-10-11  ...    27     30       17
# 4    3726  TOR      MTL           2023-10-11  ...    19     24       16
# ..    ...  ...      ...                  ...  ...   ...    ...      ...
# 690  3600  BUF      NYR  2023-11-27 00:00:00  ...    25     26       22
# 691  3600  FLA      OTT  2023-11-27 00:00:00  ...    20     20       15
# 692  3512  TBL      COL  2023-11-27 00:00:00  ...    19     22       16
# 693  3875  VGK      CGY  2023-11-27 00:00:00  ...    32     34       25
# 694  3496  WSH      SJS  2023-11-27 00:00:00  ...    21     23       15
#
#      evShots  ppSaves  ppShots  gamesPlayed  fantasyPoints  decisionType  \
# 0         23        6        7            1            3.6             W
# 1         29        5        5            1            0.4             L
# 2         23       10       10            1            8.4             W
# 3         19        6        6            1            3.4             W
# 4         20        3        4            1           -2.2             W
# ..       ...      ...      ...          ...            ...           ...
# 690       22        3        4            1            7.0             W
# 691       15        4        4            1           11.0             W
# 692       18        3        4            1           -2.2             L
# 693       27        4        4            1            3.4           OTL
# 694       16        4        5            1            0.2             L
#
#      available
# 0        61.94
# 1        16.39
# 2         6.91
# 3        53.03
# 4        34.22
# ..         ...
# 690      93.63
# 691      29.30
# 692       6.12
# 693       6.91
# 694      80.79
#
# [695 rows x 25 columns]

# %%
top_goalies = goalies.sort_values('fantasyPoints', ascending=False)
top_goalies = top_goalies.head(24)
top_goalies_list = top_goalies['name'].tolist()
filtered_box = allG_df[allG_df['name'].isin(top_goalies_list)]

filtered_box['name'].nunique()
# Out:
# 24

# %%
filtered_box['fantasyPoints'].describe()
# Out:
# count    299.000000
# mean       3.022074
# std        5.203424
# min       -8.600000
# 25%       -0.800000
# 50%        3.200000
# 75%        6.700000
# max       15.200000
# Name: fantasyPoints, dtype: float64

# %%
owned_goalies = allG_df.loc[allG_df['available'] <= 60]
goalie_list = owned_goalies['name'].unique()
owned_goalies['name'].nunique()
# Out:
# 24

# %%
owned_goalies['fantasyPoints'].describe()
# Out:
# count    303.000000
# mean       2.385479
# std        5.187535
# min       -8.800000
# 25%       -1.700000
# 50%        2.600000
# 75%        6.400000
# max       15.200000
# Name: fantasyPoints, dtype: float64

# %%
notowned_goalies = allG_df.loc[allG_df['available'] > 60]
notowned_goalies['name'].nunique()
# Out:
# 52

# %%
notowned_goalies['fantasyPoints'].describe()
# Out:
# count    392.000000
# mean       1.207143
# std        5.116859
# min      -14.800000
# 25%       -2.600000
# 50%        1.000000
# 75%        4.800000
# max       14.600000
# Name: fantasyPoints, dtype: float64

# %%
average = owned_goalies['fantasyPoints'].mean()

# %%
goalie_list
filtered_goalies = goalies[goalies['name'].isin(goalie_list)]
remaining_goalies = goalies[~goalies['name'].isin(goalie_list)]

filtered_goalies.sort_values('roster_percent', ascending=False, inplace=True)
remaining_goalies.sort_values('roster_percent', ascending=False, inplace=True)

# %%
for index, row in filtered_goalies.iterrows():
    temp = allG_df.loc[allG_df['playerId'] == row['playerId']]
    temp.sort_values('gameDate', ascending=True, inplace=True)
    teamESPN = team_names_only.loc[team_names_only['abbreviation'] == row['team'], 'name'].iloc[0]
    crease = summary_statsG.loc[summary_statsG['playerId'] == row['playerId'], 'creaseShare'].iloc[0]
    aas = 0
    bas = 0
    aar = 0
    bar = 0
    neg = 0
    tot = 0
    for i, r in temp.iterrows():
        if r['start'] == 1:
            if r['fantasyPoints'] > average:
                aas += 1
            else:
                bas += 1
        else:
            if r['fantasyPoints'] > average:
                aar += 1
            else:
                bar += 1
        if r['fantasyPoints'] < 0:
            neg += 1
            tot += r['fantasyPoints']
    print(f"<p><b>{row['fullName']}, G, {teamESPN}</b> (rostered in: {round(row['roster_percent'], 1)}%) <br />")
    print(f"Above average: {aas}; Below average: {bas}; Relief (above/below): {aar}/{bar}; Minus appearances: {neg} ({round(tot, 1)} total) <br />")
    print(f"{str(round((aas+aar)/(aas+bas+aar+bar)*100, 1))}% of appearances above average; {round(crease, 1)}% crease share; {round(row['fantasyPoints'], 1)} fantasy points</p>")
    print()
    print(f"<p>")
    print()
# Out:
# <p><b>Igor Shesterkin, G, New York Rangers</b> (rostered in: 99.6%) <br />
# Above average: 8; Below average: 4; Relief (above/below): 0/0; Minus appearances: 4 (-15.2 total) <br />
# 66.7% of appearances above average; 57.5% crease share; 35.6 fantasy points</p>
#
# <p>
#
# <p><b>Connor Hellebuyck, G, Winnipeg Jets</b> (rostered in: 99.2%) <br />
# Above average: 9; Below average: 6; Relief (above/below): 0/0; Minus appearances: 5 (-14.8 total) <br />
# 60.0% of appearances above average; 74.9% crease share; 42.8 fantasy points</p>
#
# <p>
#
# <p><b>Jake Oettinger, G, Dallas Stars</b> (rostered in: 98.9%) <br />
# Above average: 9; Below average: 5; Relief (above/below): 0/0; Minus appearances: 3 (-12.4 total) <br />
# 64.3% of appearances above average; 73.8% crease share; 35.4 fantasy points</p>
#
# <p>
#
# <p><b>Linus Ullmark, G, Boston Bruins</b> (rostered in: 98.2%) <br />
# Above average: 7; Below average: 3; Relief (above/below): 0/1; Minus appearances: 4 (-12.2 total) <br />
# 63.6% of appearances above average; 50.3% crease share; 35.2 fantasy points</p>
#
# <p>
#
# <p><b>Alexandar Georgiev, G, Colorado Avalanche</b> (rostered in: 96.3%) <br />
# Above average: 10; Below average: 8; Relief (above/below): 0/0; Minus appearances: 5 (-24.0 total) <br />
# 55.6% of appearances above average; 83.8% crease share; 43.2 fantasy points</p>
#
# <p>
#
# <p><b>Ilya Sorokin, G, New York Islanders</b> (rostered in: 95.9%) <br />
# Above average: 6; Below average: 7; Relief (above/below): 0/0; Minus appearances: 5 (-8.8 total) <br />
# 46.2% of appearances above average; 65.5% crease share; 39.2 fantasy points</p>
#
# <p>
#
# <p><b>Thatcher Demko, G, Vancouver Canucks</b> (rostered in: 94.6%) <br />
# Above average: 11; Below average: 4; Relief (above/below): 0/0; Minus appearances: 4 (-15.8 total) <br />
# 73.3% of appearances above average; 67.2% crease share; 61.0 fantasy points</p>
#
# <p>
#
# <p><b>Jeremy Swayman, G, Boston Bruins</b> (rostered in: 94.5%) <br />
# Above average: 7; Below average: 4; Relief (above/below): 0/0; Minus appearances: 4 (-4.6 total) <br />
# 63.6% of appearances above average; 49.7% crease share; 44.4 fantasy points</p>
#
# <p>
#
# <p><b>Andrei Vasilevskiy, G, Tampa Bay Lightning</b> (rostered in: 93.9%) <br />
# Above average: 1; Below average: 1; Relief (above/below): 0/0; Minus appearances: 1 (-2.2 total) <br />
# 50.0% of appearances above average; 9.0% crease share; 2.2 fantasy points</p>
#
# <p>
#
# <p><b>Adin Hill, G, Vegas Golden Knights</b> (rostered in: 93.1%) <br />
# Above average: 8; Below average: 5; Relief (above/below): 0/0; Minus appearances: 3 (-4.6 total) <br />
# 61.5% of appearances above average; 59.4% crease share; 64.4 fantasy points</p>
#
# <p>
#
# <p><b>Juuse Saros, G, Nashville Predators</b> (rostered in: 88.3%) <br />
# Above average: 7; Below average: 9; Relief (above/below): 0/0; Minus appearances: 8 (-28.6 total) <br />
# 43.8% of appearances above average; 76.4% crease share; 19.8 fantasy points</p>
#
# <p>
#
# <p><b>Tristan Jarry, G, Pittsburgh Penguins</b> (rostered in: 83.6%) <br />
# Above average: 8; Below average: 7; Relief (above/below): 0/0; Minus appearances: 5 (-21.0 total) <br />
# 53.3% of appearances above average; 70.0% crease share; 44.8 fantasy points</p>
#
# <p>
#
# <p><b>Cam Talbot, G, Los Angeles Kings</b> (rostered in: 80.8%) <br />
# Above average: 9; Below average: 4; Relief (above/below): 1/0; Minus appearances: 3 (-9.0 total) <br />
# 71.4% of appearances above average; 72.5% crease share; 63.2 fantasy points</p>
#
# <p>
#
# <p><b>Logan Thompson, G, Vegas Golden Knights</b> (rostered in: 76.1%) <br />
# Above average: 5; Below average: 4; Relief (above/below): 0/0; Minus appearances: 2 (-2.4 total) <br />
# 55.6% of appearances above average; 40.6% crease share; 28.4 fantasy points</p>
#
# <p>
#
# <p><b>Vitek Vanecek, G, New Jersey Devils</b> (rostered in: 74.7%) <br />
# Above average: 6; Below average: 7; Relief (above/below): 0/1; Minus appearances: 6 (-17.4 total) <br />
# 42.9% of appearances above average; 67.2% crease share; 12.2 fantasy points</p>
#
# <p>
#
# <p><b>Carter Hart, G, Philadelphia Flyers</b> (rostered in: 74.5%) <br />
# Above average: 6; Below average: 6; Relief (above/below): 0/0; Minus appearances: 6 (-13.6 total) <br />
# 50.0% of appearances above average; 52.8% crease share; 28.2 fantasy points</p>
#
# <p>
#
# <p><b>Sergei Bobrovsky, G, Florida Panthers</b> (rostered in: 70.7%) <br />
# Above average: 9; Below average: 8; Relief (above/below): 0/0; Minus appearances: 6 (-9.4 total) <br />
# 52.9% of appearances above average; 81.0% crease share; 48.2 fantasy points</p>
#
# <p>
#
# <p><b>Ilya Samsonov, G, Toronto Maple Leafs</b> (rostered in: 65.8%) <br />
# Above average: 3; Below average: 7; Relief (above/below): 0/0; Minus appearances: 5 (-16.2 total) <br />
# 30.0% of appearances above average; 45.0% crease share; 1.8 fantasy points</p>
#
# <p>
#
# <p><b>Filip Gustavsson, G, Minnesota Wild</b> (rostered in: 64.3%) <br />
# Above average: 2; Below average: 9; Relief (above/below): 0/0; Minus appearances: 7 (-29.6 total) <br />
# 18.2% of appearances above average; 53.1% crease share; -7.8 fantasy points</p>
#
# <p>
#
# <p><b>Jacob Markstrom, G, Calgary Flames</b> (rostered in: 51.5%) <br />
# Above average: 5; Below average: 9; Relief (above/below): 0/0; Minus appearances: 5 (-12.2 total) <br />
# 35.7% of appearances above average; 63.1% crease share; 14.4 fantasy points</p>
#
# <p>
#
# <p><b>Jordan Binnington, G, St. Louis Blues</b> (rostered in: 50.6%) <br />
# Above average: 7; Below average: 6; Relief (above/below): 0/2; Minus appearances: 7 (-27.6 total) <br />
# 46.7% of appearances above average; 68.8% crease share; 28.0 fantasy points</p>
#
# <p>
#
# <p><b>Stuart Skinner, G, Edmonton Oilers</b> (rostered in: 47.9%) <br />
# Above average: 6; Below average: 8; Relief (above/below): 0/1; Minus appearances: 9 (-36.8 total) <br />
# 40.0% of appearances above average; 69.1% crease share; 2.4 fantasy points</p>
#
# <p>
#
# <p><b>Frederik Andersen, G, Carolina Hurricanes</b> (rostered in: 47.0%) <br />
# Above average: 3; Below average: 3; Relief (above/below): 0/0; Minus appearances: 2 (-2.8 total) <br />
# 50.0% of appearances above average; 26.1% crease share; 11.4 fantasy points</p>
#
# <p>
#
# <p><b>Joseph Woll, G, Toronto Maple Leafs</b> (rostered in: 40.5%) <br />
# Above average: 3; Below average: 6; Relief (above/below): 2/0; Minus appearances: 4 (-14.0 total) <br />
# 45.5% of appearances above average; 55.0% crease share; 24.4 fantasy points</p>
#
# <p>

# %%
for index, row in remaining_goalies.iterrows():
    temp = allG_df.loc[allG_df['playerId'] == row['playerId']]
    temp.sort_values('gameDate', ascending=True, inplace=True)
    teamESPN = team_names_only.loc[team_names_only['abbreviation'] == row['team'], 'name'].iloc[0]
    crease = summary_statsG.loc[summary_statsG['playerId'] == row['playerId'], 'creaseShare'].iloc[0]
    aas = 0
    bas = 0
    aar = 0
    bar = 0
    neg = 0
    tot = 0
    for i, r in temp.iterrows():
        if r['start'] == 1:
            if r['fantasyPoints'] > average:
                aas += 1
            else:
                bas += 1
        else:
            if r['fantasyPoints'] > average:
                aar += 1
            else:
                bar += 1
        if r['fantasyPoints'] < 0:
            neg += 1
            tot += r['fantasyPoints']
    print(f"<p><b>{row['fullName']}, G, {teamESPN}</b> (rostered in: {round(row['roster_percent'], 1)}%) <br />")
    print(f"Above average: {aas}; Below average: {bas}; Relief (above/below): {aar}/{bar}; Minus appearances: {neg} ({round(tot, 1)} total) <br />")
    print(f"{str(round((aas+aar)/(aas+bas+aar+bar)*100, 1))}% of appearances above average; {round(crease, 1)}% crease share; {round(row['fantasyPoints'], 1)} fantasy points</p>")
    print()
    print(f"<p>")
    print()
# Out:
# <p><b>Jonas Johansson, G, Tampa Bay Lightning</b> (rostered in: 38.1%) <br />
# Above average: 7; Below average: 10; Relief (above/below): 0/0; Minus appearances: 5 (-19.0 total) <br />
# 41.2% of appearances above average; 77.6% crease share; 25.2 fantasy points</p>
#
# <p>
#
# <p><b>Jonathan Quick, G, New York Rangers</b> (rostered in: 32.3%) <br />
# Above average: 5; Below average: 2; Relief (above/below): 0/1; Minus appearances: 0 (0 total) <br />
# 62.5% of appearances above average; 37.5% crease share; 41.0 fantasy points</p>
#
# <p>
#
# <p><b>Joonas Korpisalo, G, Ottawa Senators</b> (rostered in: 31.3%) <br />
# Above average: 5; Below average: 6; Relief (above/below): 0/1; Minus appearances: 4 (-14.8 total) <br />
# 41.7% of appearances above average; 63.2% crease share; 14.4 fantasy points</p>
#
# <p>
#
# <p><b>Pyotr Kochetkov, G, Carolina Hurricanes</b> (rostered in: 29.0%) <br />
# Above average: 2; Below average: 3; Relief (above/below): 0/2; Minus appearances: 5 (-14.0 total) <br />
# 28.6% of appearances above average; 30.8% crease share; 1.6 fantasy points</p>
#
# <p>
#
# <p><b>Ville Husso, G, Detroit Red Wings</b> (rostered in: 28.1%) <br />
# Above average: 4; Below average: 7; Relief (above/below): 0/0; Minus appearances: 5 (-9.4 total) <br />
# 36.4% of appearances above average; 54.8% crease share; 13.4 fantasy points</p>
#
# <p>
#
# <p><b>John Gibson, G, Anaheim Ducks</b> (rostered in: 23.8%) <br />
# Above average: 6; Below average: 7; Relief (above/below): 0/1; Minus appearances: 6 (-13.4 total) <br />
# 42.9% of appearances above average; 60.9% crease share; 17.4 fantasy points</p>
#
# <p>
#
# <p><b>Semyon Varlamov, G, New York Islanders</b> (rostered in: 21.9%) <br />
# Above average: 3; Below average: 4; Relief (above/below): 0/0; Minus appearances: 2 (-3.8 total) <br />
# 42.9% of appearances above average; 34.5% crease share; 29.6 fantasy points</p>
#
# <p>
#
# <p><b>Devon Levi, G, Buffalo Sabres</b> (rostered in: 20.4%) <br />
# Above average: 2; Below average: 6; Relief (above/below): 0/1; Minus appearances: 6 (-17.0 total) <br />
# 22.2% of appearances above average; 37.9% crease share; -5.0 fantasy points</p>
#
# <p>
#
# <p><b>Darcy Kuemper, G, Washington Capitals</b> (rostered in: 19.2%) <br />
# Above average: 4; Below average: 6; Relief (above/below): 0/0; Minus appearances: 4 (-18.0 total) <br />
# 40.0% of appearances above average; 56.1% crease share; 8.4 fantasy points</p>
#
# <p>
#
# <p><b>Charlie Lindgren, G, Washington Capitals</b> (rostered in: 14.2%) <br />
# Above average: 4; Below average: 2; Relief (above/below): 0/0; Minus appearances: 2 (-5.8 total) <br />
# 66.7% of appearances above average; 32.9% crease share; 26.4 fantasy points</p>
#
# <p>
#
# <p><b>Marc-Andre Fleury, G, Minnesota Wild</b> (rostered in: 13.6%) <br />
# Above average: 3; Below average: 5; Relief (above/below): 1/0; Minus appearances: 5 (-23.0 total) <br />
# 44.4% of appearances above average; 46.9% crease share; -4.6 fantasy points</p>
#
# <p>
#
# <p><b>Antti Raanta, G, Carolina Hurricanes</b> (rostered in: 12.7%) <br />
# Above average: 5; Below average: 4; Relief (above/below): 1/0; Minus appearances: 4 (-26.2 total) <br />
# 60.0% of appearances above average; 43.1% crease share; 2.0 fantasy points</p>
#
# <p>
#
# <p><b>Connor Ingram, G, Arizona Coyotes</b> (rostered in: 10.8%) <br />
# Above average: 6; Below average: 4; Relief (above/below): 0/1; Minus appearances: 3 (-9.0 total) <br />
# 54.5% of appearances above average; 49.2% crease share; 38.4 fantasy points</p>
#
# <p>
#
# <p><b>Petr Mrazek, G, Chicago Blackhawks</b> (rostered in: 10.8%) <br />
# Above average: 3; Below average: 7; Relief (above/below): 0/1; Minus appearances: 4 (-11.0 total) <br />
# 27.3% of appearances above average; 52.3% crease share; 12.6 fantasy points</p>
#
# <p>
#
# <p><b>Elvis Merzlikins, G, Columbus Blue Jackets</b> (rostered in: 9.1%) <br />
# Above average: 6; Below average: 10; Relief (above/below): 0/0; Minus appearances: 7 (-13.8 total) <br />
# 37.5% of appearances above average; 64.6% crease share; 21.2 fantasy points</p>
#
# <p>
#
# <p><b>Lukas Dostal, G, Anaheim Ducks</b> (rostered in: 9.0%) <br />
# Above average: 3; Below average: 5; Relief (above/below): 1/0; Minus appearances: 3 (-24.0 total) <br />
# 44.4% of appearances above average; 39.1% crease share; 0.6 fantasy points</p>
#
# <p>
#
# <p><b>James Reimer, G, Detroit Red Wings</b> (rostered in: 7.9%) <br />
# Above average: 3; Below average: 3; Relief (above/below): 0/0; Minus appearances: 3 (-4.4 total) <br />
# 50.0% of appearances above average; 30.4% crease share; 16.0 fantasy points</p>
#
# <p>
#
# <p><b>Philipp Grubauer, G, Seattle Kraken</b> (rostered in: 7.6%) <br />
# Above average: 4; Below average: 8; Relief (above/below): 0/0; Minus appearances: 6 (-17.2 total) <br />
# 33.3% of appearances above average; 47.8% crease share; 3.2 fantasy points</p>
#
# <p>
#
# <p><b>Karel Vejmelka, G, Arizona Coyotes</b> (rostered in: 6.6%) <br />
# Above average: 3; Below average: 7; Relief (above/below): 0/1; Minus appearances: 7 (-22.2 total) <br />
# 27.3% of appearances above average; 50.8% crease share; -2.4 fantasy points</p>
#
# <p>
#
# <p><b>Casey DeSmith, G, Vancouver Canucks</b> (rostered in: 6.4%) <br />
# Above average: 4; Below average: 3; Relief (above/below): 0/1; Minus appearances: 3 (-8.6 total) <br />
# 50.0% of appearances above average; 32.8% crease share; 14.0 fantasy points</p>
#
# <p>
#
# <p><b>Ukko-Pekka Luukkonen, G, Buffalo Sabres</b> (rostered in: 6.4%) <br />
# Above average: 6; Below average: 3; Relief (above/below): 1/1; Minus appearances: 3 (-9.8 total) <br />
# 63.6% of appearances above average; 44.9% crease share; 34.0 fantasy points</p>
#
# <p>
#
# <p><b>Jake Allen, G, Montréal Canadiens</b> (rostered in: 6.1%) <br />
# Above average: 3; Below average: 6; Relief (above/below): 0/0; Minus appearances: 4 (-13.6 total) <br />
# 33.3% of appearances above average; 39.1% crease share; 9.0 fantasy points</p>
#
# <p>
#
# <p><b>Alex Lyon, G, Detroit Red Wings</b> (rostered in: 5.8%) <br />
# Above average: 2; Below average: 1; Relief (above/below): 0/0; Minus appearances: 1 (-0.8 total) <br />
# 66.7% of appearances above average; 14.8% crease share; 18.8 fantasy points</p>
#
# <p>
#
# <p><b>Pheonix Copley, G, Los Angeles Kings</b> (rostered in: 4.1%) <br />
# Above average: 3; Below average: 3; Relief (above/below): 0/0; Minus appearances: 3 (-15.4 total) <br />
# 50.0% of appearances above average; 27.5% crease share; 6.0 fantasy points</p>
#
# <p>
#
# <p><b>Akira Schmid, G, New Jersey Devils</b> (rostered in: 3.0%) <br />
# Above average: 0; Below average: 6; Relief (above/below): 0/1; Minus appearances: 2 (-10.0 total) <br />
# 0.0% of appearances above average; 32.8% crease share; -2.0 fantasy points</p>
#
# <p>
#
# <p><b>Mackenzie Blackwood, G, San Jose Sharks</b> (rostered in: 2.6%) <br />
# Above average: 6; Below average: 8; Relief (above/below): 0/2; Minus appearances: 7 (-38.2 total) <br />
# 37.5% of appearances above average; 64.5% crease share; 5.6 fantasy points</p>
#
# <p>
#
# <p><b>Joel Hofer, G, St. Louis Blues</b> (rostered in: 2.6%) <br />
# Above average: 4; Below average: 3; Relief (above/below): 1/0; Minus appearances: 3 (-15.2 total) <br />
# 62.5% of appearances above average; 31.2% crease share; 21.4 fantasy points</p>
#
# <p>
#
# <p><b>Jack Campbell, G, Edmonton Oilers</b> (rostered in: 2.5%) <br />
# Above average: 1; Below average: 4; Relief (above/below): 0/0; Minus appearances: 4 (-19.2 total) <br />
# 20.0% of appearances above average; 22.4% crease share; -8.6 fantasy points</p>
#
# <p>
#
# <p><b>Alex Nedeljkovic, G, Pittsburgh Penguins</b> (rostered in: 2.4%) <br />
# Above average: 2; Below average: 2; Relief (above/below): 0/0; Minus appearances: 1 (-2.0 total) <br />
# 50.0% of appearances above average; 20.0% crease share; 19.6 fantasy points</p>
#
# <p>
#
# <p><b>Sam Montembeault, G, Montréal Canadiens</b> (rostered in: 2.1%) <br />
# Above average: 4; Below average: 4; Relief (above/below): 1/0; Minus appearances: 2 (-8.2 total) <br />
# 55.6% of appearances above average; 41.6% crease share; 16.6 fantasy points</p>
#
# <p>
#
# <p><b>Anton Forsberg, G, Ottawa Senators</b> (rostered in: 1.5%) <br />
# Above average: 3; Below average: 3; Relief (above/below): 0/1; Minus appearances: 4 (-24.2 total) <br />
# 42.9% of appearances above average; 36.8% crease share; -7.0 fantasy points</p>
#
# <p>
#
# <p><b>Joey Daccord, G, Seattle Kraken</b> (rostered in: 1.5%) <br />
# Above average: 4; Below average: 6; Relief (above/below): 0/2; Minus appearances: 4 (-12.2 total) <br />
# 33.3% of appearances above average; 52.2% crease share; 6.6 fantasy points</p>
#
# <p>
#
# <p><b>Dustin Wolf, G, Calgary Flames</b> (rostered in: 1.5%) <br />
# Above average: 0; Below average: 1; Relief (above/below): 0/0; Minus appearances: 1 (-1.2 total) <br />
# 0.0% of appearances above average; 4.5% crease share; -1.2 fantasy points</p>
#
# <p>
#
# <p><b>Scott Wedgewood, G, Dallas Stars</b> (rostered in: 1.3%) <br />
# Above average: 4; Below average: 1; Relief (above/below): 0/0; Minus appearances: 1 (-2.0 total) <br />
# 80.0% of appearances above average; 26.2% crease share; 18.6 fantasy points</p>
#
# <p>
#
# <p><b>Arvid Soderblom, G, Chicago Blackhawks</b> (rostered in: 1.1%) <br />
# Above average: 2; Below average: 7; Relief (above/below): 0/1; Minus appearances: 6 (-26.2 total) <br />
# 20.0% of appearances above average; 47.7% crease share; -9.0 fantasy points</p>
#
# <p>
#
# <p><b>Ivan Prosvetov, G, Colorado Avalanche</b> (rostered in: 0.8%) <br />
# Above average: 2; Below average: 1; Relief (above/below): 0/2; Minus appearances: 2 (-6.0 total) <br />
# 40.0% of appearances above average; 16.2% crease share; 10.2 fantasy points</p>
#
# <p>
#
# <p><b>Anthony Stolarz, G, Florida Panthers</b> (rostered in: 0.8%) <br />
# Above average: 2; Below average: 2; Relief (above/below): 0/0; Minus appearances: 1 (-4.0 total) <br />
# 50.0% of appearances above average; 19.0% crease share; 14.0 fantasy points</p>
#
# <p>
#
# <p><b>Samuel Ersson, G, Philadelphia Flyers</b> (rostered in: 0.5%) <br />
# Above average: 4; Below average: 3; Relief (above/below): 0/1; Minus appearances: 4 (-18.6 total) <br />
# 50.0% of appearances above average; 37.7% crease share; 8.6 fantasy points</p>
#
# <p>
#
# <p><b>Kevin Lankinen, G, Nashville Predators</b> (rostered in: 0.5%) <br />
# Above average: 3; Below average: 1; Relief (above/below): 0/1; Minus appearances: 2 (-4.2 total) <br />
# 60.0% of appearances above average; 23.6% crease share; 13.4 fantasy points</p>
#
# <p>
#
# <p><b>Laurent Brossoit, G, Winnipeg Jets</b> (rostered in: 0.5%) <br />
# Above average: 1; Below average: 4; Relief (above/below): 0/0; Minus appearances: 2 (-5.0 total) <br />
# 20.0% of appearances above average; 25.1% crease share; 0.4 fantasy points</p>
#
# <p>
#
# <p><b>Dan Vladar, G, Calgary Flames</b> (rostered in: 0.4%) <br />
# Above average: 3; Below average: 4; Relief (above/below): 0/0; Minus appearances: 3 (-9.6 total) <br />
# 42.9% of appearances above average; 32.4% crease share; 5.6 fantasy points</p>
#
# <p>
#
# <p><b>Louis Domingue, G, New York Rangers</b> (rostered in: 0.4%) <br />
# Above average: 1; Below average: 0; Relief (above/below): 0/0; Minus appearances: 0 (0 total) <br />
# 100.0% of appearances above average; 5.0% crease share; 7.0 fantasy points</p>
#
# <p>
#
# <p><b>Cayden Primeau, G, Montréal Canadiens</b> (rostered in: 0.3%) <br />
# Above average: 2; Below average: 2; Relief (above/below): 0/0; Minus appearances: 2 (-7.0 total) <br />
# 50.0% of appearances above average; 19.2% crease share; 4.6 fantasy points</p>
#
# <p>
#
# <p><b>Calvin Pickard, G, Edmonton Oilers</b> (rostered in: 0.3%) <br />
# Above average: 0; Below average: 1; Relief (above/below): 0/1; Minus appearances: 1 (-2.4 total) <br />
# 0.0% of appearances above average; 8.6% crease share; -1.8 fantasy points</p>
#
# <p>
#
# <p><b>Eric Comrie, G, Buffalo Sabres</b> (rostered in: 0.3%) <br />
# Above average: 1; Below average: 4; Relief (above/below): 0/0; Minus appearances: 4 (-10.2 total) <br />
# 20.0% of appearances above average; 17.2% crease share; -3.4 fantasy points</p>
#
# <p>
#
# <p><b>Kaapo Kahkonen, G, San Jose Sharks</b> (rostered in: 0.2%) <br />
# Above average: 2; Below average: 6; Relief (above/below): 0/1; Minus appearances: 5 (-20.6 total) <br />
# 22.2% of appearances above average; 33.1% crease share; -3.8 fantasy points</p>
#
# <p>
#
# <p><b>Spencer Martin, G, Columbus Blue Jackets</b> (rostered in: 0.2%) <br />
# Above average: 3; Below average: 4; Relief (above/below): 1/1; Minus appearances: 5 (-16.2 total) <br />
# 44.4% of appearances above average; 35.4% crease share; 5.4 fantasy points</p>
#
# <p>
#
# <p><b>Magnus Hellberg, G, Pittsburgh Penguins</b> (rostered in: 0.1%) <br />
# Above average: 1; Below average: 0; Relief (above/below): 0/2; Minus appearances: 1 (-1.0 total) <br />
# 33.3% of appearances above average; 10.0% crease share; 5.8 fantasy points</p>
#
# <p>
#
# <p><b>Matt Tomkins, G, Tampa Bay Lightning</b> (rostered in: 0.1%) <br />
# Above average: 1; Below average: 2; Relief (above/below): 0/0; Minus appearances: 2 (-2.6 total) <br />
# 33.3% of appearances above average; 13.4% crease share; 0.0 fantasy points</p>
#
# <p>
#
# <p><b>Cal Petersen, G, Philadelphia Flyers</b> (rostered in: 0.1%) <br />
# Above average: 1; Below average: 1; Relief (above/below): 0/0; Minus appearances: 1 (-5.0 total) <br />
# 50.0% of appearances above average; 9.5% crease share; 2.0 fantasy points</p>
#
# <p>
#
# <p><b>Hunter Shepard, G, Washington Capitals</b> (rostered in: 0.1%) <br />
# Above average: 1; Below average: 1; Relief (above/below): 0/0; Minus appearances: 1 (-0.4 total) <br />
# 50.0% of appearances above average; 11.0% crease share; 8.8 fantasy points</p>
#
# <p>
#
# <p><b>Magnus Chrona, G, San Jose Sharks</b> (rostered in: 0.0%) <br />
# Above average: 0; Below average: 0; Relief (above/below): 0/1; Minus appearances: 1 (-5.4 total) <br />
# 0.0% of appearances above average; 2.3% crease share; -5.4 fantasy points</p>
#
# <p>

# %%
negative_starts = allG_df.loc[allG_df['fantasyPoints'] < 0]
negative_starts = negative_starts.loc[negative_starts['start'] == 1]
negative_starts['opponent'].value_counts()
negatives = negative_starts.groupby('opponent').sum().sort_values('start', ascending=False)

print("<p>")
for index, row in negatives.iterrows():
    team = team_names_only.loc[team_names_only['abbreviation'] == index, 'name'].iloc[0]
    print(f"{index}: {int(row['start'])} negatives; {round(row['fantasyPoints'], 1)} fantasy points <br />")
print("</p>")
# Out:
# <p>
# COL: 14 negatives; -50.8 fantasy points <br />
# TBL: 12 negatives; -56.4 fantasy points <br />
# NYR: 12 negatives; -36.2 fantasy points <br />
# LAK: 12 negatives; -44.6 fantasy points <br />
# DAL: 11 negatives; -33.8 fantasy points <br />
# DET: 11 negatives; -40.6 fantasy points <br />
# WPG: 10 negatives; -29.0 fantasy points <br />
# VAN: 10 negatives; -52.2 fantasy points <br />
# NJD: 9 negatives; -23.2 fantasy points <br />
# BOS: 9 negatives; -19.4 fantasy points <br />
# VGK: 9 negatives; -34.6 fantasy points <br />
# TOR: 9 negatives; -34.0 fantasy points <br />
# NSH: 8 negatives; -24.8 fantasy points <br />
# PHI: 8 negatives; -29.2 fantasy points <br />
# ANA: 8 negatives; -26.4 fantasy points <br />
# FLA: 8 negatives; -23.4 fantasy points <br />
# MTL: 7 negatives; -10.4 fantasy points <br />
# BUF: 7 negatives; -20.2 fantasy points <br />
# CAR: 7 negatives; -22.8 fantasy points <br />
# OTT: 7 negatives; -29.8 fantasy points <br />
# EDM: 7 negatives; -30.4 fantasy points <br />
# PIT: 7 negatives; -24.0 fantasy points <br />
# ARI: 7 negatives; -38.4 fantasy points <br />
# STL: 7 negatives; -29.8 fantasy points <br />
# CGY: 6 negatives; -21.4 fantasy points <br />
# CBJ: 6 negatives; -16.6 fantasy points <br />
# SEA: 6 negatives; -23.6 fantasy points <br />
# CHI: 5 negatives; -13.8 fantasy points <br />
# SJS: 5 negatives; -14.4 fantasy points <br />
# NYI: 5 negatives; -11.8 fantasy points <br />
# WSH: 5 negatives; -15.0 fantasy points <br />
# MIN: 4 negatives; -13.8 fantasy points <br />
# </p>

# %%
skinner = allG_df.loc[allG_df['name'] == 'A. Hill']
skinner = skinner.loc[skinner['gameDate'] >= '2023-11-12']
# skinner.groupby('name').sum()
skinner
# Out:
#      playerId  sweaterNumber     name position  pim  goalsAgainst   toi team  \
# 541   8478499             33  A. Hill        G    0             5  3600  VGK
# 571   8478499             33  A. Hill        G    0             2  3594  VGK
# 623   8478499             33  A. Hill        G    0             1  3717  VGK
# 693   8478499             33  A. Hill        G    0             2  3875  VGK
#
#     opponent             gameDate  ... saves  shots  evSaves  evShots  \
# 541      MTL  2023-11-16 00:00:00  ...    23     28       17       22
# 571      PIT  2023-11-19 00:00:00  ...    30     32       26       28
# 623      DAL  2023-11-22 00:00:00  ...    31     32       27       28
# 693      CGY  2023-11-27 00:00:00  ...    32     34       25       27
#
#      ppSaves  ppShots  gamesPlayed  fantasyPoints  decisionType  available
# 541        4        4            1           -1.4             W       6.91
# 571        4        4            1            2.0             L       6.91
# 623        3        3            1            8.2             W       6.91
# 693        4        4            1            3.4           OTL       6.91
#
# [4 rows x 25 columns]

# %%
summary_statsG.sort_values('fantasyPoints')
# Out:
#     playerId           name team position    toi  gamesPlayed  saves  shots  \
# 75   8482821   A. Soderblom  CHI        G  32396           10    255    289
# 10   8475789    J. Campbell  EDM        G  16007            5    137    157
# 56   8479406  F. Gustavsson  MIN        G  36534           11    296    336
# 17   8476341    A. Forsberg  OTT        G  22557            7    125    147
# 67   8480992      M. Chrona  SJS        G   1830            1     13     17
# ..       ...            ...  ...      ...    ...          ...    ...    ...
# 30   8477465       T. Jarry  PIT        G  50175           15    379    413
# 8    8475683   S. Bobrovsky  FLA        G  60661           17    426    468
# 34   8477967       T. Demko  VAN        G  52944           15    395    427
# 7    8475660      C. Talbot  LAK        G  49933           14    376    404
# 47   8478499        A. Hill  VGK        G  47683           13    362    388
#
#     shutout  fantasyPoints  missedGames  creaseShare  gamesRemaining  FPP60  \
# 75        0           -9.0            0        47.67              30  -1.00
# 10        0           -8.6            0        22.37              13  -1.93
# 56        1           -7.8            0        53.09              33  -0.77
# 17        0           -7.0            0        36.77              23  -1.12
# 67        0           -5.4            0         2.32               1 -10.62
# ..      ...            ...          ...          ...             ...    ...
# 30        3           44.8            0        70.00              43   3.21
# 8         2           48.2            0        81.05              49   2.86
# 34        2           61.0            0        67.19              40   4.15
# 7         1           63.2            0        72.50              45   4.56
# 47        2           64.4            0        59.44              35   4.86
#
#     FPPG  fantasyPointsRemain
# 75 -0.90               -30.04
# 10 -1.72               -26.83
# 56 -0.71               -25.71
# 17 -1.00               -26.70
# 67 -5.40               -14.76
# ..   ...                  ...
# 30  2.99               139.51
# 8   2.84               141.42
# 34  4.07               167.21
# 7   4.51               208.11
# 47  4.95               173.41
#
# [76 rows x 16 columns]
